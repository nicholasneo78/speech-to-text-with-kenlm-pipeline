# %%
import numpy as np
import pandas as pd
import os
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import matplotlib.pyplot as plt

# %%
EMOTIONS = {1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 0:'surprise'} # surprise index change from 8 to 0
EMOTIONS_SEL = {1:'neutral', 3:'happy', 4:'sad', 5:'angry', 6:'fear'}
DATA_PATH = 'audio_speech_actors_01-24/'
SAVE_PATH = './'
SAMPLE_RATE = 48000

# %%
data = pd.DataFrame(columns=['Emotion', 'Path']) #'Emotion intensity', 'Gender','Path'])
for dirname, _, filenames in os.walk(DATA_PATH):
    for filename in filenames:
        file_path = os.path.join(dirname, filename)
        identifiers = filename.split('.')[0].split('-')
        emotion = (int(identifiers[2]))
        if emotion == 8: # promeni surprise sa 8 na 0
            emotion = 0
        if int(identifiers[3]) == 1:
            emotion_intensity = 'normal' 
        else:
            emotion_intensity = 'strong'
        if int(identifiers[6])%2 == 0:
            gender = 'female'
        else:
            gender = 'male'
        
        # data = data.append({"Emotion": emotion,
        #                     "Emotion intensity": emotion_intensity,
        #                     "Gender": gender,
        #                     "Path": file_path
        #                      },
        #                      ignore_index = True
        #                   )
        if emotion not in [2,7,0]:
            data = data.append({"Emotion": emotion,
                                "Path": file_path
                                 },
                                 ignore_index = True
                              )

# %%
print("number of files is {}".format(len(data)))
data.head()
# Out:
# number of files is 864
#   Emotion                                               Path
# 0       1  audio_speech_actors_01-24/Actor_09/03-01-01-01...
# 1       3  audio_speech_actors_01-24/Actor_09/03-01-03-02...
# 2       5  audio_speech_actors_01-24/Actor_09/03-01-05-01...
# 3       5  audio_speech_actors_01-24/Actor_09/03-01-05-01...
# 4       4  audio_speech_actors_01-24/Actor_09/03-01-04-02...

# %%
# # number of examples per gender
# fig = plt.figure()
# ax = fig.add_subplot(111)
# counts = data['Gender'].value_counts()
# ax.bar(x=[0,1], height=counts.values)
# ax.set_xticks(ticks=[0,1])
# ax.set_xticklabels(list(counts.index))
# ax.set_xlabel('Gender')
# ax.set_ylabel('Number of examples')

# %%
# # number of examples per emotion intensity
# fig = plt.figure()
# ax = fig.add_subplot(111)
# counts = data['Emotion intensity'].value_counts()
# ax.bar(x=[0,1], height=counts.values)
# ax.set_xticks(ticks=[0,1])
# ax.set_xticklabels(list(counts.index))
# ax.set_xlabel('Gender')
# ax.set_ylabel('Number of examples')

# %%
# loading the signals
mel_spectrograms = []
signals = []
for i, file_path in enumerate(data.Path):
    audio, sample_rate = librosa.load(file_path, duration=3, offset=0.5, sr=SAMPLE_RATE)
    signal = np.zeros((int(SAMPLE_RATE*3,)))
    signal[:len(audio)] = audio
    signals.append(signal)
    print("\r Processed {}/{} files".format(i,len(data)),end='')
signals = np.stack(signals,axis=0)
# Out:
#  Processed 863/864 files

# %%
# split the data
X = signals
train_ind,test_ind,val_ind = [],[],[]
X_train,X_val,X_test = [],[],[]
Y_train,Y_val,Y_test = [],[],[]
for emotion in EMOTIONS_SEL.keys():
    emotion_ind = list(data.loc[data.Emotion==emotion,'Emotion'].index)
    emotion_ind = np.random.permutation(emotion_ind)
    m = len(emotion_ind)
    ind_train = emotion_ind[:int(0.8*m)]
    ind_val = emotion_ind[int(0.8*m):int(0.9*m)]
    ind_test = emotion_ind[int(0.9*m):]
    X_train.append(X[ind_train,:])
    Y_train.append(np.array([emotion]*len(ind_train),dtype=np.int32))
    X_val.append(X[ind_val,:])
    Y_val.append(np.array([emotion]*len(ind_val),dtype=np.int32))
    X_test.append(X[ind_test,:])
    Y_test.append(np.array([emotion]*len(ind_test),dtype=np.int32))
    train_ind.append(ind_train)
    test_ind.append(ind_test)
    val_ind.append(ind_val)
X_train = np.concatenate(X_train,0)
X_val = np.concatenate(X_val,0)
X_test = np.concatenate(X_test,0)
Y_train = np.concatenate(Y_train,0)
Y_val = np.concatenate(Y_val,0)
Y_test = np.concatenate(Y_test,0)
train_ind = np.concatenate(train_ind,0)
val_ind = np.concatenate(val_ind,0)
test_ind = np.concatenate(test_ind,0)
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# check if all are unique
unique, count = np.unique(np.concatenate([train_ind,test_ind,val_ind],0), return_counts=True)
print("Number of unique indexes is {}, out of {}".format(sum(count==1), X.shape[0]))

del X
# Out:
# X_train:(688, 144000), Y_train:(688,)
# X_val:(86, 144000), Y_val:(86,)
# X_test:(90, 144000), Y_test:(90,)
# Number of unique indexes is 864, out of 864

# %%
# augment signals by adding AWGN
def addAWGN(signal, num_bits=16, augmented_num=2, snr_low=15, snr_high=30): 
    signal_len = len(signal)
    # Generate White Gaussian noise
    noise = np.random.normal(size=(augmented_num, signal_len))
    # Normalize signal and noise
    norm_constant = 2.0**(num_bits-1)
    signal_norm = signal / norm_constant
    noise_norm = noise / norm_constant
    # Compute signal and noise power
    s_power = np.sum(signal_norm ** 2) / signal_len
    n_power = np.sum(noise_norm ** 2, axis=1) / signal_len
    # Random SNR: Uniform [15, 30] in dB
    target_snr = np.random.randint(snr_low, snr_high)
    # Compute K (covariance matrix) for each noise 
    K = np.sqrt((s_power / n_power) * 10 ** (- target_snr / 10))
    K = np.ones((signal_len, augmented_num)) * K  
    # Generate noisy signal
    return signal + K.T * noise

# %%
aug_signals = []
aug_labels = []
for i in range(X_train.shape[0]):
    signal = X_train[i,:]
    augmented_signals = addAWGN(signal)
    for j in range(augmented_signals.shape[0]):
        aug_labels.append(data.loc[i,"Emotion"])
        aug_signals.append(augmented_signals[j,:])
        data = data.append(data.iloc[i], ignore_index=True)
    print("\r Processed {}/{} files".format(i,X_train.shape[0]),end='')
aug_signals = np.stack(aug_signals,axis=0)
X_train = np.concatenate([X_train,aug_signals],axis=0)
aug_labels = np.stack(aug_labels,axis=0)
Y_train = np.concatenate([Y_train,aug_labels])
print('')
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
# Out:
#  Processed 687/688 files
# X_train:(2064, 144000), Y_train:(2064,)

# %%
# calculate mel spectrogram
def getMELspectrogram(audio, sample_rate):
    mel_spec = librosa.feature.melspectrogram(y=audio,
                                              sr=sample_rate,
                                              n_fft=1024,
                                              win_length = 512,
                                              window='hamming',
                                              hop_length = 256,
                                              n_mels=128,
                                              fmax=sample_rate/2
                                             )
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    return mel_spec_db

# %%
# test function
audio, sample_rate = librosa.load(data.loc[0,'Path'], duration=3, offset=0.5,sr=SAMPLE_RATE)
signal = np.zeros((int(SAMPLE_RATE*3,)))
signal[:len(audio)] = audio
mel_spectrogram = getMELspectrogram(signal, SAMPLE_RATE)
librosa.display.specshow(mel_spectrogram, y_axis='mel', x_axis='time')
print('MEL spectrogram shape: ',mel_spectrogram.shape)
# Out:
# MEL spectrogram shape:  (128, 563)

# %%
mel_train = []
print("Calculating mel spectrograms for train set")
for i in range(X_train.shape[0]):
    mel_spectrogram = getMELspectrogram(X_train[i,:], sample_rate=SAMPLE_RATE)
    mel_train.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_train.shape[0]),end='')
print('')
mel_train = np.stack(mel_train,axis=0)
del X_train
X_train = mel_train

mel_val = []
print("Calculating mel spectrograms for val set")
for i in range(X_val.shape[0]):
    mel_spectrogram = getMELspectrogram(X_val[i,:], sample_rate=SAMPLE_RATE)
    mel_val.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_val.shape[0]),end='')
print('')
mel_val = np.stack(mel_val,axis=0)
del X_val
X_val = mel_val

mel_test = []
print("Calculating mel spectrograms for test set")
for i in range(X_test.shape[0]):
    mel_spectrogram = getMELspectrogram(X_test[i,:], sample_rate=SAMPLE_RATE)
    mel_test.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_test.shape[0]),end='')
print('')
mel_test = np.stack(mel_test,axis=0)
del X_test
X_test = mel_test

print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# Out:
# Calculating mel spectrograms for train set
#  Processed 2063/2064 files
# Calculating mel spectrograms for val set
#  Processed 85/86 files
# Calculating mel spectrograms for test set
#  Processed 89/90 files
# X_train:(2064, 128, 563), Y_train:(2064,)
# X_val:(86, 128, 563), Y_val:(86,)
# X_test:(90, 128, 563), Y_test:(90,)

# %%
import torch
import torch.nn as nn

class ParallelModel(nn.Module):
    def __init__(self,num_emotions):
        super().__init__()
        # conv block
        self.conv2Dblock = nn.Sequential(
            # 1. conv block
            nn.Conv2d(in_channels=1,
                       out_channels=16,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),
            # 2. conv block
            nn.Conv2d(in_channels=16,
                       out_channels=32,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            # 3. conv block
            nn.Conv2d(in_channels=32,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            # 4. conv block
            nn.Conv2d(in_channels=64,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3)
        )
        # Transformer block
        self.transf_maxpool = nn.MaxPool2d(kernel_size=[2,4], stride=[2,4])
        transf_layer = nn.TransformerEncoderLayer(d_model=64, nhead=4, dim_feedforward=512, dropout=0.4, activation='relu')
        self.transf_encoder = nn.TransformerEncoder(transf_layer, num_layers=4)
        # Linear softmax layer
        self.out_linear = nn.Linear(320,num_emotions)
        self.dropout_linear = nn.Dropout(p=0)
        self.out_softmax = nn.Softmax(dim=1)
    def forward(self,x):
        # conv embedding
        conv_embedding = self.conv2Dblock(x) #(b,channel,freq,time)
        conv_embedding = torch.flatten(conv_embedding, start_dim=1) # do not flatten batch dimension
        # transformer embedding
        x_reduced = self.transf_maxpool(x)
        x_reduced = torch.squeeze(x_reduced,1)
        x_reduced = x_reduced.permute(2,0,1) # requires shape = (time,batch,embedding)
        transf_out = self.transf_encoder(x_reduced)
        transf_embedding = torch.mean(transf_out, dim=0)
        # concatenate
        complete_embedding = torch.cat([conv_embedding, transf_embedding], dim=1) 
        # final Linear
        output_logits = self.out_linear(complete_embedding)
        output_logits = self.dropout_linear(output_logits)
        output_softmax = self.out_softmax(output_logits)
        return output_logits, output_softmax

# %%
def loss_fnc(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions,target=targets)

# %%
# training
def make_train_step(model, loss_fnc, optimizer):
    def train_step(X,Y):
        # set model to train mode
        model.train()
        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        # compute loss
        loss = loss_fnc(output_logits, Y)
        # compute gradients
        loss.backward()
        # update parameters and zero gradients
        optimizer.step()
        optimizer.zero_grad()
        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,loss_fnc):
    def validate(X,Y):
        with torch.no_grad():
            model.eval()
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            loss = loss_fnc(output_logits,Y)
        return loss.item(), accuracy*100, predictions
    return validate

# %%
# scale data
from sklearn.preprocessing import StandardScaler

X_train = np.expand_dims(X_train,1)
X_val = np.expand_dims(X_val,1)
X_test = np.expand_dims(X_test,1)

scaler = StandardScaler()

b,c,h,w = X_train.shape
X_train = np.reshape(X_train, newshape=(b,-1))
X_train = scaler.fit_transform(X_train)
X_train = np.reshape(X_train, newshape=(b,c,h,w))

b,c,h,w = X_test.shape
X_test = np.reshape(X_test, newshape=(b,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, newshape=(b,c,h,w))

b,c,h,w = X_val.shape
X_val = np.reshape(X_val, newshape=(b,-1))
X_val = scaler.transform(X_val)
X_val = np.reshape(X_val, newshape=(b,c,h,w))

# %%
# train the model
EPOCHS=200
DATASET_SIZE = X_train.shape[0]
BATCH_SIZE = 32
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Selected device is {}'.format(device))
model = ParallelModel(num_emotions=len(EMOTIONS)).to(device)
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )
OPTIMIZER = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

train_step = make_train_step(model, loss_fnc, optimizer=OPTIMIZER)
validate = make_validate_fnc(model,loss_fnc)
# Out:
# Selected device is cuda
# Number of trainable params:  395176

# %%
losses=[]
val_losses = []
for epoch in range(EPOCHS):
    # shuffle data
    ind = np.random.permutation(DATASET_SIZE)
    X_train = X_train[ind,:,:,:]
    Y_train = Y_train[ind]
    epoch_acc = 0
    epoch_loss = 0
    iters = int(DATASET_SIZE / BATCH_SIZE)
    for i in range(iters):
        batch_start = i * BATCH_SIZE
        batch_end = min(batch_start + BATCH_SIZE, DATASET_SIZE)
        actual_batch_size = batch_end-batch_start
        X = X_train[batch_start:batch_end,:,:,:]
        Y = Y_train[batch_start:batch_end]
        X_tensor = torch.tensor(X,device=device).float()
        Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
        loss, acc = train_step(X_tensor,Y_tensor)
        epoch_acc += acc*actual_batch_size/DATASET_SIZE
        epoch_loss += loss*actual_batch_size/DATASET_SIZE
        print(f"\r Epoch {epoch}: iteration {i}/{iters}",end='')
    X_val_tensor = torch.tensor(X_val,device=device).float()
    Y_val_tensor = torch.tensor(Y_val,dtype=torch.long,device=device)
    val_loss, val_acc, predictions = validate(X_val_tensor,Y_val_tensor)
    losses.append(epoch_loss)
    val_losses.append(val_loss)
    print('')
    print(f"Epoch {epoch} --> loss:{epoch_loss:.4f}, acc:{epoch_acc:.2f}%, val_loss:{val_loss:.4f}, val_acc:{val_acc:.2f}%")
# Out:
#  Epoch 0: iteration 63/64
# Epoch 0 --> loss:1.9727, acc:21.90%, val_loss:1.6482, val_acc:32.56%
#  Epoch 1: iteration 63/64
# Epoch 1 --> loss:1.6852, acc:23.74%, val_loss:1.5012, val_acc:30.23%
#  Epoch 2: iteration 63/64
# Epoch 2 --> loss:1.6177, acc:27.23%, val_loss:1.4408, val_acc:31.40%
#  Epoch 3: iteration 63/64
# Epoch 3 --> loss:1.5658, acc:29.02%, val_loss:1.4501, val_acc:41.86%
#  Epoch 4: iteration 63/64
# Epoch 4 --> loss:1.5344, acc:30.09%, val_loss:1.2555, val_acc:48.84%
#  Epoch 5: iteration 63/64
# Epoch 5 --> loss:1.5162, acc:32.27%, val_loss:1.2831, val_acc:43.02%
#  Epoch 6: iteration 63/64
# Epoch 6 --> loss:1.4922, acc:31.40%, val_loss:1.1845, val_acc:45.35%
#  Epoch 7: iteration 63/64
# Epoch 7 --> loss:1.4919, acc:33.09%, val_loss:1.1565, val_acc:48.84%
#  Epoch 8: iteration 63/64
# Epoch 8 --> loss:1.5035, acc:33.53%, val_loss:1.1750, val_acc:53.49%
#  Epoch 9: iteration 63/64
# Epoch 9 --> loss:1.4711, acc:34.16%, val_loss:1.2400, val_acc:51.16%
#  Epoch 10: iteration 63/64
# Epoch 10 --> loss:1.4283, acc:35.76%, val_loss:1.0943, val_acc:52.33%
#  Epoch 11: iteration 63/64
# Epoch 11 --> loss:1.4331, acc:35.08%, val_loss:1.1326, val_acc:47.67%
#  Epoch 12: iteration 63/64
# Epoch 12 --> loss:1.4296, acc:35.22%, val_loss:0.9538, val_acc:66.28%
#  Epoch 13: iteration 63/64
# Epoch 13 --> loss:1.4028, acc:36.48%, val_loss:0.9988, val_acc:60.47%
#  Epoch 14: iteration 63/64
# Epoch 14 --> loss:1.3934, acc:36.39%, val_loss:1.0847, val_acc:59.30%
#  Epoch 15: iteration 63/64
# Epoch 15 --> loss:1.4050, acc:38.03%, val_loss:1.0361, val_acc:56.98%
#  Epoch 16: iteration 63/64
# Epoch 16 --> loss:1.3591, acc:38.32%, val_loss:1.1436, val_acc:54.65%
#  Epoch 17: iteration 63/64
# Epoch 17 --> loss:1.3757, acc:37.79%, val_loss:0.8545, val_acc:65.12%
#  Epoch 18: iteration 63/64
# Epoch 18 --> loss:1.3548, acc:38.66%, val_loss:0.8494, val_acc:65.12%
#  Epoch 19: iteration 63/64
# Epoch 19 --> loss:1.3397, acc:40.50%, val_loss:0.8951, val_acc:65.12%
#  Epoch 20: iteration 63/64
# Epoch 20 --> loss:1.3258, acc:41.18%, val_loss:0.8964, val_acc:67.44%
#  Epoch 21: iteration 63/64
# Epoch 21 --> loss:1.3325, acc:41.33%, val_loss:1.1966, val_acc:50.00%
#  Epoch 22: iteration 63/64
# Epoch 22 --> loss:1.3179, acc:38.91%, val_loss:0.9648, val_acc:59.30%
#  Epoch 23: iteration 63/64
# Epoch 23 --> loss:1.3113, acc:39.97%, val_loss:1.1302, val_acc:54.65%
#  Epoch 24: iteration 63/64
# Epoch 24 --> loss:1.2814, acc:41.57%, val_loss:0.9672, val_acc:61.63%
#  Epoch 25: iteration 63/64
# Epoch 25 --> loss:1.2826, acc:42.10%, val_loss:0.9372, val_acc:66.28%
#  Epoch 26: iteration 63/64
# Epoch 26 --> loss:1.2982, acc:41.52%, val_loss:0.8965, val_acc:65.12%
#  Epoch 27: iteration 63/64
# Epoch 27 --> loss:1.2985, acc:40.94%, val_loss:0.8560, val_acc:63.95%
#  Epoch 28: iteration 63/64
# Epoch 28 --> loss:1.2751, acc:42.25%, val_loss:1.1916, val_acc:55.81%
#  Epoch 29: iteration 63/64
# Epoch 29 --> loss:1.2613, acc:43.60%, val_loss:0.8854, val_acc:61.63%
#  Epoch 30: iteration 63/64
# Epoch 30 --> loss:1.2580, acc:42.54%, val_loss:0.7264, val_acc:67.44%
#  Epoch 31: iteration 63/64
# Epoch 31 --> loss:1.2592, acc:43.31%, val_loss:0.8395, val_acc:66.28%
#  Epoch 32: iteration 63/64
# Epoch 32 --> loss:1.2657, acc:42.01%, val_loss:1.1158, val_acc:56.98%
#  Epoch 33: iteration 63/64
# Epoch 33 --> loss:1.2452, acc:44.53%, val_loss:1.1087, val_acc:55.81%
#  Epoch 34: iteration 63/64
# Epoch 34 --> loss:1.2213, acc:45.11%, val_loss:0.7590, val_acc:69.77%
#  Epoch 35: iteration 63/64
# Epoch 35 --> loss:1.2173, acc:44.91%, val_loss:0.8829, val_acc:66.28%
#  Epoch 36: iteration 63/64
# Epoch 36 --> loss:1.2222, acc:45.93%, val_loss:1.2431, val_acc:59.30%
#  Epoch 37: iteration 63/64
# Epoch 37 --> loss:1.2026, acc:45.35%, val_loss:0.8428, val_acc:62.79%
#  Epoch 38: iteration 63/64
# Epoch 38 --> loss:1.1997, acc:45.59%, val_loss:0.8166, val_acc:70.93%
#  Epoch 39: iteration 63/64
# Epoch 39 --> loss:1.1915, acc:45.98%, val_loss:0.9896, val_acc:62.79%
#  Epoch 40: iteration 63/64
# Epoch 40 --> loss:1.1979, acc:46.03%, val_loss:0.7288, val_acc:72.09%
#  Epoch 41: iteration 63/64
# Epoch 41 --> loss:1.2047, acc:46.12%, val_loss:0.9817, val_acc:66.28%
#  Epoch 42: iteration 63/64
# Epoch 42 --> loss:1.1743, acc:46.61%, val_loss:0.7837, val_acc:69.77%
#  Epoch 43: iteration 63/64
# Epoch 43 --> loss:1.1595, acc:48.40%, val_loss:1.0436, val_acc:62.79%
#  Epoch 44: iteration 63/64
# Epoch 44 --> loss:1.1673, acc:48.16%, val_loss:0.9001, val_acc:66.28%
#  Epoch 45: iteration 63/64
# Epoch 45 --> loss:1.1460, acc:49.56%, val_loss:0.7924, val_acc:66.28%
#  Epoch 46: iteration 63/64
# Epoch 46 --> loss:1.1695, acc:47.58%, val_loss:0.8948, val_acc:67.44%
#  Epoch 47: iteration 63/64
# Epoch 47 --> loss:1.1310, acc:48.45%, val_loss:1.0447, val_acc:69.77%
#  Epoch 48: iteration 63/64
# Epoch 48 --> loss:1.1200, acc:49.71%, val_loss:1.1351, val_acc:63.95%
#  Epoch 49: iteration 63/64
# Epoch 49 --> loss:1.1450, acc:49.18%, val_loss:0.8401, val_acc:66.28%
#  Epoch 50: iteration 63/64
# Epoch 50 --> loss:1.1275, acc:49.52%, val_loss:0.8683, val_acc:59.30%
#  Epoch 51: iteration 63/64
# Epoch 51 --> loss:1.1354, acc:48.69%, val_loss:1.0545, val_acc:60.47%
#  Epoch 52: iteration 63/64
# Epoch 52 --> loss:1.1325, acc:49.22%, val_loss:0.8563, val_acc:66.28%
#  Epoch 53: iteration 63/64
# Epoch 53 --> loss:1.0890, acc:52.37%, val_loss:0.9275, val_acc:67.44%
#  Epoch 54: iteration 63/64
# Epoch 54 --> loss:1.0843, acc:51.60%, val_loss:0.7896, val_acc:67.44%
#  Epoch 55: iteration 63/64
# Epoch 55 --> loss:1.0884, acc:51.65%, val_loss:0.9432, val_acc:68.60%
#  Epoch 56: iteration 63/64
# Epoch 56 --> loss:1.0984, acc:52.42%, val_loss:1.0670, val_acc:65.12%
#  Epoch 57: iteration 63/64
# Epoch 57 --> loss:1.0749, acc:52.13%, val_loss:0.9258, val_acc:68.60%
#  Epoch 58: iteration 63/64
# Epoch 58 --> loss:1.0641, acc:51.79%, val_loss:1.1622, val_acc:61.63%
#  Epoch 59: iteration 63/64
# Epoch 59 --> loss:1.0965, acc:51.02%, val_loss:1.0493, val_acc:62.79%
#  Epoch 60: iteration 63/64
# Epoch 60 --> loss:1.0640, acc:52.23%, val_loss:1.1452, val_acc:66.28%
#  Epoch 61: iteration 63/64
# Epoch 61 --> loss:1.0411, acc:53.63%, val_loss:1.0391, val_acc:66.28%
#  Epoch 62: iteration 63/64
# Epoch 62 --> loss:1.0613, acc:54.02%, val_loss:1.0824, val_acc:69.77%
#  Epoch 63: iteration 63/64
# Epoch 63 --> loss:1.0581, acc:53.92%, val_loss:1.1551, val_acc:61.63%
#  Epoch 64: iteration 63/64
# Epoch 64 --> loss:1.0640, acc:53.59%, val_loss:0.9637, val_acc:67.44%
#  Epoch 65: iteration 63/64
# Epoch 65 --> loss:1.0587, acc:54.36%, val_loss:1.0572, val_acc:63.95%
#  Epoch 66: iteration 63/64
# Epoch 66 --> loss:1.0196, acc:54.02%, val_loss:1.1699, val_acc:62.79%
#  Epoch 67: iteration 63/64
# Epoch 67 --> loss:1.0145, acc:56.40%, val_loss:0.9966, val_acc:67.44%
#  Epoch 68: iteration 63/64
# Epoch 68 --> loss:1.0255, acc:54.70%, val_loss:0.9727, val_acc:60.47%
#  Epoch 69: iteration 63/64
# Epoch 69 --> loss:0.9978, acc:56.49%, val_loss:0.8978, val_acc:69.77%
#  Epoch 70: iteration 63/64
# Epoch 70 --> loss:1.0062, acc:56.06%, val_loss:0.9904, val_acc:72.09%
#  Epoch 71: iteration 63/64
# Epoch 71 --> loss:1.0110, acc:55.52%, val_loss:1.0799, val_acc:67.44%
#  Epoch 72: iteration 63/64
# Epoch 72 --> loss:0.9893, acc:57.46%, val_loss:1.0126, val_acc:67.44%
#  Epoch 73: iteration 63/64
# Epoch 73 --> loss:0.9767, acc:57.85%, val_loss:1.0237, val_acc:67.44%
#  Epoch 74: iteration 63/64
# Epoch 74 --> loss:0.9820, acc:56.54%, val_loss:0.8624, val_acc:75.58%
#  Epoch 75: iteration 63/64
# Epoch 75 --> loss:0.9788, acc:57.99%, val_loss:1.6683, val_acc:60.47%
#  Epoch 76: iteration 63/64
# Epoch 76 --> loss:0.9735, acc:58.67%, val_loss:1.8913, val_acc:51.16%
#  Epoch 77: iteration 63/64
# Epoch 77 --> loss:1.0083, acc:56.40%, val_loss:0.9244, val_acc:68.60%
#  Epoch 78: iteration 63/64
# Epoch 78 --> loss:0.9444, acc:58.77%, val_loss:1.0135, val_acc:67.44%
#  Epoch 79: iteration 63/64
# Epoch 79 --> loss:0.9684, acc:59.79%, val_loss:1.2241, val_acc:66.28%
#  Epoch 80: iteration 63/64
# Epoch 80 --> loss:0.9574, acc:58.38%, val_loss:1.2166, val_acc:66.28%
#  Epoch 81: iteration 63/64
# Epoch 81 --> loss:0.9555, acc:59.16%, val_loss:1.4194, val_acc:60.47%
#  Epoch 82: iteration 63/64
# Epoch 82 --> loss:0.9096, acc:61.68%, val_loss:1.3846, val_acc:67.44%
#  Epoch 83: iteration 63/64
# Epoch 83 --> loss:0.9002, acc:61.58%, val_loss:1.2003, val_acc:70.93%
#  Epoch 84: iteration 63/64
# Epoch 84 --> loss:0.9143, acc:61.72%, val_loss:1.7323, val_acc:58.14%
#  Epoch 85: iteration 63/64
# Epoch 85 --> loss:0.9034, acc:61.05%, val_loss:1.2996, val_acc:62.79%
#  Epoch 86: iteration 63/64
# Epoch 86 --> loss:0.8823, acc:62.40%, val_loss:1.5209, val_acc:63.95%
#  Epoch 87: iteration 63/64
# Epoch 87 --> loss:0.9131, acc:61.19%, val_loss:1.4570, val_acc:65.12%
#  Epoch 88: iteration 63/64
# Epoch 88 --> loss:0.8829, acc:62.02%, val_loss:1.2022, val_acc:68.60%
#  Epoch 89: iteration 63/64
# Epoch 89 --> loss:0.8741, acc:63.57%, val_loss:1.4115, val_acc:61.63%
#  Epoch 90: iteration 63/64
# Epoch 90 --> loss:0.8489, acc:64.58%, val_loss:1.3846, val_acc:60.47%
#  Epoch 91: iteration 63/64
# Epoch 91 --> loss:0.8594, acc:64.58%, val_loss:1.4184, val_acc:56.98%
#  Epoch 92: iteration 63/64
# Epoch 92 --> loss:0.8538, acc:63.57%, val_loss:1.5843, val_acc:61.63%
#  Epoch 93: iteration 63/64
# Epoch 93 --> loss:0.8569, acc:63.91%, val_loss:1.5947, val_acc:60.47%
#  Epoch 94: iteration 63/64
# Epoch 94 --> loss:0.8403, acc:64.92%, val_loss:1.6335, val_acc:61.63%
#  Epoch 95: iteration 63/64
# Epoch 95 --> loss:0.8524, acc:64.78%, val_loss:1.8987, val_acc:56.98%
#  Epoch 96: iteration 63/64
# Epoch 96 --> loss:0.8400, acc:64.97%, val_loss:1.5593, val_acc:65.12%
#  Epoch 97: iteration 63/64
# Epoch 97 --> loss:0.8470, acc:64.58%, val_loss:1.1883, val_acc:61.63%
#  Epoch 98: iteration 63/64
# Epoch 98 --> loss:0.8158, acc:65.84%, val_loss:1.5826, val_acc:58.14%
#  Epoch 99: iteration 63/64
# Epoch 99 --> loss:0.7882, acc:67.39%, val_loss:1.4360, val_acc:59.30%
#  Epoch 100: iteration 63/64
# Epoch 100 --> loss:0.7641, acc:68.27%, val_loss:1.6550, val_acc:56.98%
#  Epoch 101: iteration 63/64
# Epoch 101 --> loss:0.8280, acc:65.79%, val_loss:1.3976, val_acc:63.95%
#  Epoch 102: iteration 63/64
# Epoch 102 --> loss:0.7990, acc:66.96%, val_loss:1.5762, val_acc:61.63%
#  Epoch 103: iteration 63/64
# Epoch 103 --> loss:0.7680, acc:68.90%, val_loss:1.5409, val_acc:61.63%
#  Epoch 104: iteration 63/64
# Epoch 104 --> loss:0.7193, acc:69.67%, val_loss:2.0903, val_acc:53.49%
#  Epoch 105: iteration 63/64
# Epoch 105 --> loss:0.7926, acc:66.86%, val_loss:1.5492, val_acc:65.12%
#  Epoch 106: iteration 63/64
# Epoch 106 --> loss:0.7638, acc:67.59%, val_loss:1.2927, val_acc:65.12%
#  Epoch 107: iteration 63/64
# Epoch 107 --> loss:0.7443, acc:68.70%, val_loss:1.7929, val_acc:63.95%
#  Epoch 108: iteration 63/64
# Epoch 108 --> loss:0.7121, acc:70.64%, val_loss:1.3776, val_acc:66.28%
#  Epoch 109: iteration 63/64
# Epoch 109 --> loss:0.6948, acc:71.51%, val_loss:1.4038, val_acc:63.95%
#  Epoch 110: iteration 63/64
# Epoch 110 --> loss:0.7625, acc:69.48%, val_loss:1.5487, val_acc:65.12%
#  Epoch 111: iteration 63/64
# Epoch 111 --> loss:0.7098, acc:70.30%, val_loss:1.7478, val_acc:56.98%
#  Epoch 112: iteration 63/64
# Epoch 112 --> loss:0.7157, acc:70.20%, val_loss:1.5763, val_acc:65.12%
#  Epoch 113: iteration 63/64
# Epoch 113 --> loss:0.7056, acc:71.17%, val_loss:1.5863, val_acc:62.79%
#  Epoch 114: iteration 63/64
# Epoch 114 --> loss:0.6982, acc:72.19%, val_loss:2.1174, val_acc:55.81%
#  Epoch 115: iteration 63/64
# Epoch 115 --> loss:0.6475, acc:74.18%, val_loss:1.6138, val_acc:62.79%
#  Epoch 116: iteration 63/64
# Epoch 116 --> loss:0.6786, acc:73.11%, val_loss:2.3349, val_acc:55.81%
#  Epoch 117: iteration 63/64
# Epoch 117 --> loss:0.6996, acc:72.43%, val_loss:2.0270, val_acc:53.49%
#  Epoch 118: iteration 63/64
# Epoch 118 --> loss:0.6495, acc:74.08%, val_loss:1.6646, val_acc:65.12%
#  Epoch 119: iteration 63/64
# Epoch 119 --> loss:0.6454, acc:74.81%, val_loss:1.5132, val_acc:63.95%
#  Epoch 120: iteration 63/64
# Epoch 120 --> loss:0.6704, acc:72.92%, val_loss:1.8782, val_acc:61.63%
#  Epoch 121: iteration 63/64
# Epoch 121 --> loss:0.6092, acc:75.68%, val_loss:1.5735, val_acc:60.47%
#  Epoch 122: iteration 63/64
# Epoch 122 --> loss:0.6010, acc:75.82%, val_loss:1.6767, val_acc:62.79%
#  Epoch 123: iteration 63/64
# Epoch 123 --> loss:0.5860, acc:76.21%, val_loss:1.7188, val_acc:65.12%
#  Epoch 124: iteration 63/64
# Epoch 124 --> loss:0.5854, acc:76.21%, val_loss:1.4055, val_acc:65.12%
#  Epoch 125: iteration 63/64
# Epoch 125 --> loss:0.5987, acc:76.99%, val_loss:1.9008, val_acc:61.63%
#  Epoch 126: iteration 63/64
# Epoch 126 --> loss:0.5779, acc:75.73%, val_loss:1.6018, val_acc:60.47%
#  Epoch 127: iteration 63/64
# Epoch 127 --> loss:0.5712, acc:76.70%, val_loss:1.7226, val_acc:55.81%
#  Epoch 128: iteration 63/64
# Epoch 128 --> loss:0.5881, acc:76.31%, val_loss:1.7049, val_acc:62.79%
#  Epoch 129: iteration 63/64
# Epoch 129 --> loss:0.6068, acc:75.39%, val_loss:1.4552, val_acc:65.12%
#  Epoch 130: iteration 63/64
# Epoch 130 --> loss:0.5624, acc:77.96%, val_loss:1.7622, val_acc:61.63%
#  Epoch 131: iteration 63/64
# Epoch 131 --> loss:0.5331, acc:78.92%, val_loss:1.7623, val_acc:59.30%
#  Epoch 132: iteration 63/64
# Epoch 132 --> loss:0.5149, acc:79.75%, val_loss:1.6025, val_acc:67.44%
#  Epoch 133: iteration 63/64
# Epoch 133 --> loss:0.5217, acc:79.22%, val_loss:1.6900, val_acc:61.63%
#  Epoch 134: iteration 63/64
# Epoch 134 --> loss:0.5219, acc:79.22%, val_loss:1.8422, val_acc:62.79%
#  Epoch 135: iteration 63/64
# Epoch 135 --> loss:0.5296, acc:78.49%, val_loss:1.8526, val_acc:66.28%
#  Epoch 136: iteration 63/64
# Epoch 136 --> loss:0.5943, acc:77.13%, val_loss:2.1136, val_acc:60.47%
#  Epoch 137: iteration 63/64
# Epoch 137 --> loss:0.5813, acc:77.03%, val_loss:1.9489, val_acc:62.79%
#  Epoch 138: iteration 63/64
# Epoch 138 --> loss:0.5015, acc:80.43%, val_loss:1.8699, val_acc:59.30%
#  Epoch 139: iteration 63/64
# Epoch 139 --> loss:0.4762, acc:81.25%, val_loss:1.7217, val_acc:60.47%
#  Epoch 140: iteration 63/64
# Epoch 140 --> loss:0.4626, acc:81.78%, val_loss:1.9231, val_acc:63.95%
#  Epoch 141: iteration 63/64
# Epoch 141 --> loss:0.5530, acc:78.34%, val_loss:2.3061, val_acc:55.81%
#  Epoch 142: iteration 63/64
# Epoch 142 --> loss:0.5303, acc:78.97%, val_loss:1.5371, val_acc:66.28%
#  Epoch 143: iteration 63/64
# Epoch 143 --> loss:0.4541, acc:82.03%, val_loss:1.5916, val_acc:66.28%
#  Epoch 144: iteration 63/64
# Epoch 144 --> loss:0.4155, acc:84.11%, val_loss:1.5600, val_acc:67.44%
#  Epoch 145: iteration 63/64
# Epoch 145 --> loss:0.4140, acc:83.96%, val_loss:1.7473, val_acc:67.44%
#  Epoch 146: iteration 63/64
# Epoch 146 --> loss:0.4448, acc:83.33%, val_loss:1.6905, val_acc:62.79%
#  Epoch 147: iteration 63/64
# Epoch 147 --> loss:0.4190, acc:83.28%, val_loss:1.9608, val_acc:61.63%
#  Epoch 148: iteration 63/64
# Epoch 148 --> loss:0.4025, acc:84.16%, val_loss:1.6666, val_acc:63.95%
#  Epoch 149: iteration 63/64
# Epoch 149 --> loss:0.4253, acc:83.33%, val_loss:1.7982, val_acc:60.47%
#  Epoch 150: iteration 63/64
# Epoch 150 --> loss:0.3510, acc:86.53%, val_loss:1.9232, val_acc:62.79%
#  Epoch 151: iteration 63/64
# Epoch 151 --> loss:0.3992, acc:85.13%, val_loss:1.9412, val_acc:63.95%
#  Epoch 152: iteration 63/64
# Epoch 152 --> loss:0.4731, acc:81.44%, val_loss:1.7830, val_acc:66.28%
#  Epoch 153: iteration 63/64
# Epoch 153 --> loss:0.3571, acc:86.29%, val_loss:2.0967, val_acc:62.79%
#  Epoch 154: iteration 63/64
# Epoch 154 --> loss:0.3524, acc:86.72%, val_loss:2.2650, val_acc:62.79%
#  Epoch 155: iteration 63/64
# Epoch 155 --> loss:0.4709, acc:81.73%, val_loss:1.8040, val_acc:60.47%
#  Epoch 156: iteration 63/64
# Epoch 156 --> loss:0.4021, acc:84.79%, val_loss:2.0888, val_acc:59.30%
#  Epoch 157: iteration 63/64
# Epoch 157 --> loss:0.3720, acc:85.17%, val_loss:1.7146, val_acc:61.63%
#  Epoch 158: iteration 63/64
# Epoch 158 --> loss:0.3499, acc:86.14%, val_loss:2.1197, val_acc:60.47%
#  Epoch 159: iteration 63/64
# Epoch 159 --> loss:0.3976, acc:85.13%, val_loss:2.1330, val_acc:61.63%
#  Epoch 160: iteration 63/64
# Epoch 160 --> loss:0.4300, acc:82.51%, val_loss:1.8482, val_acc:61.63%
#  Epoch 161: iteration 63/64
# Epoch 161 --> loss:0.3053, acc:88.37%, val_loss:1.9202, val_acc:59.30%
#  Epoch 162: iteration 63/64
# Epoch 162 --> loss:0.3872, acc:85.76%, val_loss:1.7102, val_acc:63.95%
#  Epoch 163: iteration 63/64
# Epoch 163 --> loss:0.3097, acc:88.03%, val_loss:2.0403, val_acc:53.49%
#  Epoch 164: iteration 63/64
# Epoch 164 --> loss:0.3476, acc:86.87%, val_loss:2.0873, val_acc:60.47%
#  Epoch 165: iteration 63/64
# Epoch 165 --> loss:0.3595, acc:85.71%, val_loss:2.3066, val_acc:58.14%
#  Epoch 166: iteration 63/64
# Epoch 166 --> loss:0.3563, acc:85.42%, val_loss:2.1020, val_acc:62.79%
#  Epoch 167: iteration 63/64
# Epoch 167 --> loss:0.3255, acc:87.65%, val_loss:2.0496, val_acc:63.95%
#  Epoch 168: iteration 63/64
# Epoch 168 --> loss:0.2960, acc:89.20%, val_loss:2.4207, val_acc:59.30%
#  Epoch 169: iteration 63/64
# Epoch 169 --> loss:0.3658, acc:85.85%, val_loss:1.8685, val_acc:61.63%
#  Epoch 170: iteration 63/64
# Epoch 170 --> loss:0.2355, acc:90.55%, val_loss:1.8878, val_acc:63.95%
#  Epoch 171: iteration 63/64
# Epoch 171 --> loss:0.2718, acc:89.44%, val_loss:1.9824, val_acc:59.30%
#  Epoch 172: iteration 63/64
# Epoch 172 --> loss:0.3168, acc:87.40%, val_loss:2.0978, val_acc:55.81%
#  Epoch 173: iteration 63/64
# Epoch 173 --> loss:0.2648, acc:90.16%, val_loss:2.3043, val_acc:60.47%
#  Epoch 174: iteration 63/64
# Epoch 174 --> loss:0.3427, acc:86.63%, val_loss:2.1283, val_acc:58.14%
#  Epoch 175: iteration 63/64
# Epoch 175 --> loss:0.3159, acc:87.35%, val_loss:2.1398, val_acc:61.63%
#  Epoch 176: iteration 63/64
# Epoch 176 --> loss:0.2452, acc:90.36%, val_loss:1.9587, val_acc:56.98%
#  Epoch 177: iteration 63/64
# Epoch 177 --> loss:0.2076, acc:91.86%, val_loss:2.1136, val_acc:60.47%
#  Epoch 178: iteration 63/64
# Epoch 178 --> loss:0.2252, acc:91.13%, val_loss:2.2088, val_acc:58.14%
#  Epoch 179: iteration 63/64
# Epoch 179 --> loss:0.2297, acc:90.70%, val_loss:2.2334, val_acc:60.47%
#  Epoch 180: iteration 63/64
# Epoch 180 --> loss:0.2715, acc:88.81%, val_loss:1.9723, val_acc:60.47%
#  Epoch 181: iteration 63/64
# Epoch 181 --> loss:0.2532, acc:89.39%, val_loss:2.0052, val_acc:58.14%
#  Epoch 182: iteration 63/64
# Epoch 182 --> loss:0.2435, acc:90.46%, val_loss:2.4247, val_acc:55.81%
#  Epoch 183: iteration 63/64
# Epoch 183 --> loss:0.2682, acc:89.78%, val_loss:1.8774, val_acc:61.63%
#  Epoch 184: iteration 63/64
# Epoch 184 --> loss:0.2380, acc:90.21%, val_loss:2.5216, val_acc:58.14%
#  Epoch 185: iteration 63/64
# Epoch 185 --> loss:0.2547, acc:90.50%, val_loss:2.3055, val_acc:60.47%
#  Epoch 186: iteration 63/64
# Epoch 186 --> loss:0.1998, acc:92.34%, val_loss:2.7182, val_acc:56.98%
#  Epoch 187: iteration 63/64
# Epoch 187 --> loss:0.2176, acc:92.10%, val_loss:2.3286, val_acc:61.63%
#  Epoch 188: iteration 63/64
# Epoch 188 --> loss:0.2110, acc:91.18%, val_loss:2.1047, val_acc:63.95%
#  Epoch 189: iteration 63/64
# Epoch 189 --> loss:0.2068, acc:92.25%, val_loss:2.3096, val_acc:54.65%
#  Epoch 190: iteration 63/64
# Epoch 190 --> loss:0.1748, acc:93.41%, val_loss:2.4675, val_acc:52.33%
#  Epoch 191: iteration 63/64
# Epoch 191 --> loss:0.1921, acc:92.49%, val_loss:2.1531, val_acc:62.79%
#  Epoch 192: iteration 63/64
# Epoch 192 --> loss:0.2646, acc:90.12%, val_loss:2.2769, val_acc:60.47%
#  Epoch 193: iteration 63/64
# Epoch 193 --> loss:0.3286, acc:87.45%, val_loss:2.2857, val_acc:59.30%
#  Epoch 194: iteration 63/64
# Epoch 194 --> loss:0.1780, acc:93.02%, val_loss:2.0429, val_acc:60.47%
#  Epoch 195: iteration 63/64
# Epoch 195 --> loss:0.1471, acc:94.43%, val_loss:2.0611, val_acc:60.47%
#  Epoch 196: iteration 63/64
# Epoch 196 --> loss:0.1145, acc:95.45%, val_loss:2.2692, val_acc:56.98%
#  Epoch 197: iteration 63/64
# Epoch 197 --> loss:0.1903, acc:92.59%, val_loss:2.1955, val_acc:61.63%
#  Epoch 198: iteration 63/64
# Epoch 198 --> loss:0.2076, acc:91.91%, val_loss:2.0432, val_acc:62.79%
#  Epoch 199: iteration 63/64
# Epoch 199 --> loss:0.1915, acc:93.07%, val_loss:2.7705, val_acc:56.98%

# %%
os.makedirs('models',exist_ok=True)
torch.save(model.state_dict(),os.path.join(SAVE_PATH,'cnn_transf_parallel_model.pt'))
print('Model is saved to {}'.format(os.path.join(SAVE_PATH,'cnn_transf_parallel_model.pt')))
# Out:
# Model is saved to ./cnn_transf_parallel_model.pt

# %%
LOAD_PATH = os.path.join(os.getcwd(),'models')
model = ParallelModel(len(EMOTIONS))
model.load_state_dict(torch.load(os.path.join(LOAD_PATH,'cnn_transf_parallel_model.pt')))
print('Model is loaded from {}'.format(os.path.join(LOAD_PATH,'cnn_transf_parallel_model.pt')))
# Out:
# Model is loaded from /stt_with_kenlm_pipeline/models/cnn_transf_parallel_model.pt

# %%
X_test_tensor = torch.tensor(X_test,device=device).float()
Y_test_tensor = torch.tensor(Y_test,dtype=torch.long,device=device)
test_loss, test_acc, predictions = validate(X_test_tensor,Y_test_tensor)
print(f'Test loss is {test_loss:.3f}')
print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test loss is 2.541
# Test accuracy is 55.56%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

predictions = predictions.cpu().numpy()
cm = confusion_matrix(Y_test, predictions)
names = [EMOTIONS[ind] for ind in range(len(EMOTIONS_SEL))]
df_cm = pd.DataFrame(cm, index=names, columns=names)
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_15/2538274449.py in <module>
#       2 import seaborn as sn
#       3
# ----> 4 predictions = predictions.cpu().numpy()
#       5 cm = confusion_matrix(Y_test, predictions)
#       6 names = [EMOTIONS[ind] for ind in range(len(EMOTIONS_SEL))]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'cpu'

# %%
correct_strong = 0
correct_normal = 0
wrong_strong = 0
wrong_normal = 0
for i in range(len(X_test)):
    intensity = data.loc[test_ind[i],'Emotion intensity']
    if Y_test[i] == predictions[i]: # correct prediction
        if  intensity == 'normal':
            correct_normal += 1
        else:
            correct_strong += 1
    else: # wrong prediction
        if intensity == 'normal':
            wrong_normal += 1
        else:
            wrong_strong += 1
array = np.array([[wrong_normal,wrong_strong],[correct_normal,correct_strong]])
df = pd.DataFrame(array,['wrong','correct'],['normal','strong'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16}) # font size
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/conda/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/conda/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Emotion intensity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_15/4235179978.py in <module>
#       4 wrong_normal = 0
#       5 for i in range(len(X_test)):
# ----> 6     intensity = data.loc[test_ind[i],'Emotion intensity']
#       7     if Y_test[i] == predictions[i]: # correct prediction
#       8         if  intensity == 'normal':
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1098     def _getitem_tuple(self, tup: tuple):
#    1099         with suppress(IndexingError):
# -> 1100             return self._getitem_lowerdim(tup)
#    1101
#    1102         # no multi-index, so validate all of the indexers
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     860                     return section
#     861                 # This is an elided recursive call to iloc/loc
# --> 862                 return getattr(section, self.name)[new_key]
#     863
#     864         raise IndexingError("not applicable")
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Emotion intensity'

# %%
correct_male = 0
correct_female = 0
wrong_male = 0
wrong_female = 0
for i in range(len(X_test)):
    gender = data.loc[test_ind[i],'Gender']
    if Y_test[i] == predictions[i]: # correct prediction
        if  gender == 'male':
            correct_male += 1
        else:
            correct_female += 1
    else: # wrong prediction
        if gender == 'male':
            wrong_male += 1
        else:
            wrong_female += 1
array = np.array([[wrong_male,wrong_female],[correct_male,correct_female]])
df = pd.DataFrame(array,['wrong','correct'],['male','female'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16}) # font size
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/conda/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/conda/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_15/164740027.py in <module>
#       4 wrong_female = 0
#       5 for i in range(len(X_test)):
# ----> 6     gender = data.loc[test_ind[i],'Gender']
#       7     if Y_test[i] == predictions[i]: # correct prediction
#       8         if  gender == 'male':
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1098     def _getitem_tuple(self, tup: tuple):
#    1099         with suppress(IndexingError):
# -> 1100             return self._getitem_lowerdim(tup)
#    1101
#    1102         # no multi-index, so validate all of the indexers
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     860                     return section
#     861                 # This is an elided recursive call to iloc/loc
# --> 862                 return getattr(section, self.name)[new_key]
#     863
#     864         raise IndexingError("not applicable")
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Gender'

# %%
# plot the loss
plt.plot(losses,'b')
plt.plot(val_losses,'r')
plt.legend(['train loss','val loss'])
